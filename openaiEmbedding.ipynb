# %% [markdown]
# ### Embedding Techniques
# ##### converting text into vectors

# %%
from langchain_openai import OpenAIEmbeddings
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("MY_OPENAI_API_KEY")
print("API key:", api_key)

embeddings = OpenAIEmbeddings(
    model="text-embedding-3-large",
    api_key=api_key
)

text = "This is a tutorial on OPENAI embedding"
result = embeddings.embed_query(text)
print(result)
# Out:
# API key: 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
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 16
#      10 embeddings = OpenAIEmbeddings(
#      11     model="text-embedding-3-large",
#      12     api_key=api_key
#      13 )
#      15 text = "This is a tutorial on OPENAI embedding"
# ---> 16 result = embeddings.embed_query(text)
#      17 print(result)
#
# File c:\Users\sahur\OneDrive\Desktop\pythontuto\venv\lib\site-packages\langchain_openai\embeddings\base.py:752, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     742 """Call out to OpenAI's embedding endpoint for embedding query text.
#     743
#     744 Args:
#    (...)
#     749     Embedding for the text.
#     750 """
#     751 self._ensure_sync_client_available()
# --> 752 return self.embed_documents([text], **kwargs)[0]
#
# File c:\Users\sahur\OneDrive\Desktop\pythontuto\venv\lib\site-packages\langchain_openai\embeddings\base.py:702, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     699 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     700 # This could be optimized to avoid double work when all texts are short enough.
#     701 engine = cast(str, self.deployment)
# --> 702 return self._get_len_safe_embeddings(
#     703     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     704 )
#
# File c:\Users\sahur\OneDrive\Desktop\pythontuto\venv\lib\site-packages\langchain_openai\embeddings\base.py:569, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     567 # Make API call with this batch
#     568 batch_tokens = tokens[i:batch_end]
# --> 569 response = self.client.create(input=batch_tokens, **client_kwargs)
#     570 if not isinstance(response, dict):
#     571     response = response.model_dump()
#
# File c:\Users\sahur\OneDrive\Desktop\pythontuto\venv\lib\site-packages\openai\resources\embeddings.py:132, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     127                 base64.b64decode(data), dtype="float32"
#     128             ).tolist()
#     130     return obj
# --> 132 return self._post(
#     133     "/embeddings",
#     134     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     135     options=make_request_options(
#     136         extra_headers=extra_headers,
#     137         extra_query=extra_query,
#     138         extra_body=extra_body,
#     139         timeout=timeout,
#     140         post_parser=parser,
#     141     ),
#     142     cast_to=CreateEmbeddingResponse,
#     143 )
#
# File c:\Users\sahur\OneDrive\Desktop\pythontuto\venv\lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)
#    1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\sahur\OneDrive\Desktop\pythontuto\venv\lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
